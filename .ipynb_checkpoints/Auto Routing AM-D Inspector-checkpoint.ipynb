# %%
import tensorflow as tf
from tensorflow import keras
from attention_dynamic_model import AttentionDynamicModel
from utils import create_data_on_disk
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2022-10-18 06:32:02.474232: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# AM-D Model Parameters
embedding_dim   = 128
n_encode_layers = 2
n_heads         = 8
tanh_clipping   = 10

model_amd = AttentionDynamicModel(
    embedding_dim  =embedding_dim,
    n_encode_layers=n_encode_layers,
    n_heads        =n_heads,
    tanh_clipping  =tanh_clipping
)

model_amd.load_weights('checkpoints/AM-D_oct_17_20_nodes.ckp')
# Out:
# 2022-10-18 06:32:35.656365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 06:32:36.667788: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 06:32:36.668583: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 06:32:36.694576: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-18 06:32:36.695970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 06:32:36.696664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 06:32:36.697235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 06:32:43.068255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 06:32:43.068964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 06:32:43.069498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-18 06:32:43.069917: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5021 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
data = create_data_on_disk(20, 100, False, None, True, 42)

# %%
data
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(2,), dtype=tf.float32, name=None), TensorSpec(shape=(20, 2), dtype=tf.float32, name=None), TensorSpec(shape=(20,), dtype=tf.float32, name=None))>

# %%
gen_data = next(data.batch(100).as_numpy_iterator())
sample   = 0
__type   = 1 # 0: space nodes, 1: depot node
graph    = pd.DataFrame(gen_data[__type][sample], columns=['x', 'y'])

goal = {
    'x': gen_data[0][sample][0], 
    'y': gen_data[0][sample][1], 
    'type': 'depot'
}

graph = graph.assign(type='node').append(goal, ignore_index=True)

graph
# Out:
# /tmp/ipykernel_12122/3437516333.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   graph = graph.assign(type='node').append(goal, ignore_index=True)
#            x         y   type
# 0   0.657302  0.364328   node
# 1   0.118694  0.939067   node
# 2   0.074154  0.873417   node
# 3   0.253108  0.085860   node
# 4   0.706352  0.468738   node
# 5   0.776964  0.508429   node
# 6   0.570920  0.082506   node
# 7   0.419440  0.974805   node
# 8   0.945331  0.323978   node
# 9   0.450232  0.027604   node
# 10  0.477436  0.688640   node
# 11  0.814466  0.940706   node
# 12  0.162772  0.116702   node
# 13  0.960132  0.515050   node
# 14  0.378060  0.407372   node
# 15  0.602414  0.661526   node
# 16  0.642343  0.326639   node
# 17  0.264516  0.869968   node
# 18  0.111604  0.181311   node
# 19  0.871795  0.247977   node
# 20  0.952271  0.677408  depot

# %%
sns.scatterplot(data=graph, x='x', y='y', hue='type', style='type')
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
test_data = next(data.batch(5).as_numpy_iterator())
model_amd.set_decode_type('greedy')
res = model_amd(test_data, return_pi=True)
# Out:
# 2022-10-18 06:32:45.759406: W tensorflow/core/data/root_dataset.cc:266] Optimization loop failed: CANCELLED: Operation was cancelled

# %%
start_node = pd.DataFrame([test_data[0][0]])
space_nodes = pd.DataFrame(test_data[1][0])
nodes = pd.concat([start_node, space_nodes]).reset_index(drop=True)

# %%
selections = pd.DataFrame(res[2][0]).astype(int)

# %%
path = nodes.iloc[selections[0]]

# %%
path
# Out:
#            0         1
# 12  0.814466  0.940706
# 8   0.419440  0.974805
# 18  0.264516  0.869968
# 14  0.960132  0.515050
# 16  0.602414  0.661526
# 11  0.477436  0.688640
# 9   0.945331  0.323978
# 0   0.952271  0.677408
# 0   0.952271  0.677408
# 0   0.952271  0.677408
# 2   0.118694  0.939067
# 6   0.776964  0.508429
# 3   0.074154  0.873417
# 5   0.706352  0.468738
# 1   0.657302  0.364328
# 15  0.378060  0.407372
# 19  0.111604  0.181311
# 0   0.952271  0.677408
# 0   0.952271  0.677408
# 17  0.642343  0.326639
# 20  0.871795  0.247977
# 7   0.570920  0.082506
# 13  0.162772  0.116702
# 10  0.450232  0.027604
# 0   0.952271  0.677408
# 0   0.952271  0.677408
# 4   0.253108  0.085860
# 0   0.952271  0.677408
# 0   0.952271  0.677408
# 0   0.952271  0.677408

# %%
gen_data = test_data
sample   = 0
__type   = 1 # 0: space nodes, 1: depot node
graph    = pd.DataFrame(gen_data[__type][sample], columns=['x', 'y'])

goal = {
    'x': gen_data[0][sample][0], 
    'y': gen_data[0][sample][1], 
    'type': 'depot'
}

graph = graph.assign(type='node').append(goal, ignore_index=True)

graph
# Out:
# /tmp/ipykernel_12122/791374584.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   graph = graph.assign(type='node').append(goal, ignore_index=True)
#            x         y   type
# 0   0.657302  0.364328   node
# 1   0.118694  0.939067   node
# 2   0.074154  0.873417   node
# 3   0.253108  0.085860   node
# 4   0.706352  0.468738   node
# 5   0.776964  0.508429   node
# 6   0.570920  0.082506   node
# 7   0.419440  0.974805   node
# 8   0.945331  0.323978   node
# 9   0.450232  0.027604   node
# 10  0.477436  0.688640   node
# 11  0.814466  0.940706   node
# 12  0.162772  0.116702   node
# 13  0.960132  0.515050   node
# 14  0.378060  0.407372   node
# 15  0.602414  0.661526   node
# 16  0.642343  0.326639   node
# 17  0.264516  0.869968   node
# 18  0.111604  0.181311   node
# 19  0.871795  0.247977   node
# 20  0.952271  0.677408  depot

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data=graph, x='x', y='y', hue='type', style='type')
plt.show()
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(10, 10))

x = path[0].values
y = path[1].values
u = np.diff(x)
v = np.diff(y)
pos_x = x[:-1] + u/1
pos_y = y[:-1] + v/1
norm = np.sqrt(u**2+v**2)

#plt.scatter(path[0], path[1], zorder=1)
sns.scatterplot(data=graph, x='x', y='y', hue='type', style='type')
plt.plot(path[0], path[1], zorder=2)
plt.quiver(pos_x, pos_y, u/norm, v/norm, angles="xy", zorder=3, pivot="tip")

plt.show()
# Out:
# /tmp/ipykernel_12122/19499267.py:14: RuntimeWarning: invalid value encountered in divide
#   plt.quiver(pos_x, pos_y, u/norm, v/norm, angles="xy", zorder=3, pivot="tip")
